# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %%
import os

RESEARCH_DIR = "/content/drive/My Drive/Colab Notebooks/TFOD Project (beginner)/models/research"

# %%
os.chdir(RESEARCH_DIR)

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/TFOD Project (beginner)/models/research'

# %%
# !python train.py --logtostderr --train_dir=training/ --pipeline_config_path=training/faster_rcnn_inception_v2_coco.config
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/TFOD Project (beginner)/models/research/nets/inception_resnet_v2.py:373: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/TFOD Project (beginner)/models/research/nets/mobilenet/mobilenet.py:389: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From train.py:55: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# ...

# %%
# ctrl+shift+i : then copy below js code in 'console' and press enter. This will prevent colab notebook from disconnecting. (but i don't know how to stop this js from running afterwards)

# function ClickConnect(){
# console.log("Working"); 
# document.querySelector("colab-toolbar-button").click() 
# }setInterval(ClickConnect,60000)
